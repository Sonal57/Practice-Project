# %% [markdown]
# ## Abalone

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
shell = pd.read_csv('abalone.csv')
shell
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %% [markdown]
#     In above dataset of abalone we have 4177 rows and 9 columns.

# %%
shell.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %% [markdown]
# #### About the columns
#    1. Sex - Sex(M:Male,F:Female,I:Infant)
#    2. Length - Longest Shell measurement(millimetres-mm)
#    3. Diameter - Diameter-perpendicular to length(mm)
#    4. Height - Height-with meat in shell(mm)
#    5. Whole weight - Weight of whole abalone(grams)
#    6. Shucked weight - Weight of meat(grams)
#    7. Viscera weight - Gut weight after bleeding(grams)
#    8. Rings - Rings-value + 1.5 gives age in years

# %%
shell.shape
# Out:
# (4177, 9)

# %% [markdown]
# Shell dataset has 4177 rows and 9 columns.

# %%
shell.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# We can see that there is no null values in given dataset.

# %%
shell.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %% [markdown]
# We can see the informaton about shell dataset.
# It shows the rows and column in dataset. It also shows that is any null value in dataset. There are 3 datatypes object,float and int in shell dataset column.
#
# It also shows the how much memory is used by dataset.

# %% [markdown]
# ### Data Analysis and Visualization

# %% [markdown]
# #### Data description

# %%
shell.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
plt.figure(figsize=(20,12))
sns.heatmap(shell.describe(),annot=True,linewidths=2,fmt='.2f' )
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.title('Abalone')
plt.colormaps
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Outcome of Description
#
# Description of Shell datset helps us to clean the data.
#
#
# Length - 1.Mean = 0.52, 2.Std = 0.12, 3.Min = 0.07, Max = 0.81
#
# Diameter- 1.Mean = 0.41, 2.Std = 0.10, 3.Min = 0.06, Max = 0.65
#
# Height - 1.Mean = 0.14, 2.Std = 0.04, 3.Min = 0, Max = 1.13
#
# Whole weight - 1.Mean = 0.83, 2.Std = 0.49, 3.Min = 0, Max = 2.83
#
# Shucked weight - 1.Mean = 0.36, 2.Std = 0.22, 3.Min = 0, Max = 1.49
#
# Viscera weight - 1.Mean = 0.18, 2.Std = 0.11, 3.Min = 0, Max = 0.76
#
# Shell weight - 1.Mean = 0.24, 2.Std = 0.14, 3.Min = 0, Max = 1
#
# Rings - 1.Mean = 9.93, 2.Std = 3.32, 3.Min = 1, Max = 29.0

# %% [markdown]
# The discription of dataset shows the count,mean,standard deviation,minimum value,maximum value,25 percentile,50 percentile and 75 percentile of each column

# %% [markdown]
# ##### Coorelation

# %%
shell.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# ...

# %%
plt.figure(figsize=(13,10))
sns.heatmap(shell.corr(),annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Outcome of Correlation

# %% [markdown]
# As we seen in heatmap all the columns are positivel correlated with rings.
#
# Shell weight is highly correlated with the rings with 63% which consider to be a strong bond. Diameter is 57 percentage correlated with rings, which consider to be an very good bond.
#
# Height and length are 56 percentage correlated with rings. Whole weight and viscera weight are 54 and 50 percentage correlated with rings resp. which consider to be an good bond.
#
# Shucked weight is 42 percentage correlated with the rings.

# %%
shell.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %% [markdown]
# There is no null value in shell dataset.

# %%
plt.figure(figsize=(9,7))
sns.lineplot(x = 'Rings', y = 'Length',hue = 'Sex', data=shell)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Length'>

# %% [markdown]
# Above plot shows that longest the shell maximum is the number of rings.

# %%
plt.figure(figsize=(9,7))
sns.lineplot(x = 'Rings', y = 'Diameter',hue = 'Sex', data=shell)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Diameter'>

# %% [markdown]
# As shown in above plot as diameter increases the number of rings increases.

# %%
plt.figure(figsize=(9,7))
sns.lineplot(x = 'Rings', y = 'Height',hue = 'Sex', data=shell)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Height'>

# %% [markdown]
# As shown in above plot as height increases the number of rings are maximum.

# %%
plt.figure(figsize=(9,7))
sns.lineplot(x = 'Rings', y = 'Whole weight',hue = 'Sex', data=shell)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Whole weight'>

# %% [markdown]
# Above plot shows that if the weight increases the number of rings are maximum.

# %%
plt.figure(figsize=(9,7))
sns.lineplot(x = 'Rings', y = 'Shucked weight', data=shell, hue='Sex')
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Shucked weight'>

# %% [markdown]
# As seen in above plot if the shucked weight increases,the number of rings are maximum, if the the decreased the number of rings are less.

# %%
plt.figure(figsize=(9,7))
sns.lineplot(x = 'Rings', y = 'Viscera weight', data=shell, hue='Sex')
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Viscera weight'>

# %% [markdown]
# From above plot we can see that as weight increases the number of rings are increases, as weight decreased the number of rings are decreased.

# %%
plt.figure(figsize=(9,7))
sns.lineplot(x = 'Rings', y = 'Shell weight', data=shell, hue='Sex')
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Shell weight'>

# %%
sns.lineplot(x = 'Rings', y = 'Sex', data=shell)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Sex'>

# %%
sns.countplot(shell['Rings'])
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rings', ylabel='count'>

# %% [markdown]
# #### Data Conversion

# %%
from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()

# %%
for i in shell.columns:
    if shell[i].dtypes == object:
        shell[i]=enc.fit_transform(shell[i].values.reshape(-1,1))

# %%
shell
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     2.0   0.455     0.365   0.095        0.5140          0.2245
# 1     2.0   0.350     0.265   0.090        0.2255          0.0995
# 2     0.0   0.530     0.420   0.135        0.6770          0.2565
# 3     2.0   0.440     0.365   0.125        0.5160          0.2155
# 4     1.0   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172  0.0   0.565     0.450   0.165        0.8870          0.3700
# 4173  2.0   0.590     0.440   0.135        0.9660          0.4390
# 4174  2.0   0.600     0.475   0.205        1.1760          0.5255
# 4175  0.0   0.625     0.485   0.150        1.0945          0.5310
# 4176  2.0   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %% [markdown]
# We converted the Catagorical data into Numerical format.

# %% [markdown]
# ### Splitting the Independent and Target variables into x and y

# %%
x = shell.drop('Rings',axis=1)
x
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     2.0   0.455     0.365   0.095        0.5140          0.2245
# 1     2.0   0.350     0.265   0.090        0.2255          0.0995
# 2     0.0   0.530     0.420   0.135        0.6770          0.2565
# 3     2.0   0.440     0.365   0.125        0.5160          0.2155
# 4     1.0   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172  0.0   0.565     0.450   0.165        0.8870          0.3700
# 4173  2.0   0.590     0.440   0.135        0.9660          0.4390
# 4174  2.0   0.600     0.475   0.205        1.1760          0.5255
# 4175  0.0   0.625     0.485   0.150        1.0945          0.5310
# 4176  2.0   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight
# 0             0.1010        0.1500
# 1             0.0485        0.0700
# 2             0.1415        0.2100
# ...

# %%
y = shell['Rings']
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64

# %%
x.shape
# Out:
# (4177, 8)

# %%
y.shape
# Out:
# (4177,)

# %% [markdown]
# ### Skewness

# %%
shell.skew()
# Out:
# Sex              -0.098155
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %%
shell.plot(kind = 'density',subplots = True,layout =(3,3) ,figsize=(28,18),sharex=False)
plt.show()

# %% [markdown]
# We can see skewness in dataset for multiple columns.

# %%
shell.skew().sort_values(ascending=False)
# Out:
# Height            3.128817
# Rings             1.114102
# Shucked weight    0.719098
# Shell weight      0.620927
# Viscera weight    0.591852
# Whole weight      0.530959
# Sex              -0.098155
# Diameter         -0.609198
# Length           -0.639873
# dtype: float64

# %% [markdown]
# Above information shows the skewness of columns in descending order.

# %%
from sklearn.preprocessing import power_transform
x1 = power_transform(x)

# %%
type(x1)
# Out:
# numpy.ndarray

# %%
x.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight'],
#       dtype='object')

# %%
x = pd.DataFrame(x1,columns=x.columns)
x
# Out:
#            Sex    Length  Diameter    Height  Whole weight  Shucked weight  \
# 0     1.127072 -0.685502 -0.549860 -1.124512     -0.576766       -0.540989
# 1     1.127072 -1.396344 -1.387333 -1.264396     -1.351761       -1.311662
# 2    -1.307935 -0.070774  0.008537 -0.064823     -0.198099       -0.366116
# 3     1.127072 -0.797286 -0.549860 -0.320227     -0.571893       -0.591672
# 4    -0.009459 -1.513796 -1.459659 -1.549424     -1.413146       -1.380201
# ...        ...       ...       ...       ...           ...             ...
# 4172 -1.307935  0.249836  0.345636  0.666117      0.241948        0.194158
# 4173  1.127072  0.492813  0.230611 -0.064823      0.395706        0.495450
# 4174  1.127072  0.593366  0.645191  1.565082      0.777944        0.838137
# 4175 -1.307935  0.853375  0.769928  0.307083      0.633874        0.858739
# 4176  1.127072  1.834478  1.726289  1.347943      1.937323        2.103648
#
#       Viscera weight  Shell weight
# ...

# %%
x.skew().sort_values(ascending=False)
# Out:
# Viscera weight    0.039780
# Shucked weight    0.027351
# Shell weight      0.023390
# Whole weight     -0.003980
# Diameter         -0.065977
# Length           -0.066669
# Height           -0.115483
# Sex              -0.176442
# dtype: float64

# %%
sk = x.skew()
sk
# Out:
# Sex              -0.176442
# Length           -0.066669
# Diameter         -0.065977
# Height           -0.115483
# Whole weight     -0.003980
# Shucked weight    0.027351
# Viscera weight    0.039780
# Shell weight      0.023390
# dtype: float64

# %%
x.skew()[np.abs(shell.skew()<0.25)].all()
# Out:
# True

# %% [markdown]
# We remove the skewness from all the columns by using Power transform.

# %% [markdown]
# ### Checking Outliers

# %%
x.boxplot(figsize=(20,7))
plt.subplots
plt.show()

# %% [markdown]
# From the above boxplot we can see that Rings and height have the highest number of outliers. Shell weight,Diameter,Length,Shucked weight and Viscera weight have the less number of outliers.
#
# Sex has no outliers.

# %% [markdown]
# ### Removing Outliers

# %% [markdown]
# #### Z Score Technique

# %%
from scipy.stats import zscore
z = np.abs(zscore(shell))
z
# Out:
# array([[1.15198011, 0.57455813, 0.43214879, ..., 0.72621157, 0.63821689,
#         1.57154357],
#        [1.15198011, 1.44898585, 1.439929  , ..., 1.20522124, 1.21298732,
#         0.91001299],
#        [1.28068972, 0.05003309, 0.12213032, ..., 0.35668983, 0.20713907,
#         0.28962385],
#        ...,
#        [1.15198011, 0.6329849 , 0.67640943, ..., 0.97541324, 0.49695471,
#         0.28962385],
#        [1.28068972, 0.84118198, 0.77718745, ..., 0.73362741, 0.41073914,
#         0.02057072],
#        [1.15198011, 1.54905203, 1.48263359, ..., 1.78744868, 1.84048058,
#         0.64095986]])

# %%
Threshold = 3
print(np.where(z>3))
# Out:
# (array([   6,   72,   81,   83,  129,  163,  164,  165,  165,  165,  166,
#         166,  167,  168,  170,  181,  232,  236,  236,  236,  237,  237,
#         238,  238,  239,  270,  275,  277,  278,  294,  310,  313,  314,
#         334,  351,  355,  358,  358,  362,  375,  416,  417,  428,  431,
#         433,  469,  478,  480,  501,  526,  526,  530,  572,  628,  673,
#         674,  675,  678,  694,  696,  696,  719,  719,  720,  720,  744,
#         754,  756,  811,  891,  891,  891, 1048, 1051, 1051, 1052, 1193,
#        1197, 1199, 1202, 1204, 1206, 1206, 1207, 1207, 1207, 1207, 1209,
#        1209, 1257, 1417, 1417, 1418, 1422, 1426, 1427, 1427, 1427, 1428,
#        1429, 1429, 1528, 1754, 1756, 1757, 1759, 1761, 1762, 1762, 1762,
#        1763, 1763, 1763, 1821, 1982, 1986, 1987, 1987, 2051, 2090, 2108,
#        2108, 2114, 2114, 2157, 2161, 2176, 2180, 2199, 2201, 2208, 2209,
#        2274, 2275, 2305, 2334, 2334, 2334, 2335, 2344, 2358, 2368, 2381,
# ...

# %%
# model without outliers
abl = shell[(z<3).all(axis=1)]
abl
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     2.0   0.455     0.365   0.095        0.5140          0.2245
# 1     2.0   0.350     0.265   0.090        0.2255          0.0995
# 2     0.0   0.530     0.420   0.135        0.6770          0.2565
# 3     2.0   0.440     0.365   0.125        0.5160          0.2155
# 4     1.0   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172  0.0   0.565     0.450   0.165        0.8870          0.3700
# 4173  2.0   0.590     0.440   0.135        0.9660          0.4390
# 4174  2.0   0.600     0.475   0.205        1.1760          0.5255
# 4175  0.0   0.625     0.485   0.150        1.0945          0.5310
# 4176  2.0   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %% [markdown]
# After removing outliers we have got new dataset with 4132 rows and 9 columns.

# %%
print(shell.shape) #model with outliers.
print(abl.shape) #model without outliers.
# Out:
# (4177, 9)
# (4027, 9)

# %%
x = abl.iloc[:,:-1]
x.shape
# Out:
# (4027, 8)

# %%
y = abl['Rings']
y.shape
# Out:
# (4027,)

# %% [markdown]
# We split the independent and target value into x and y.

# %% [markdown]
# #### SMOTE

# %%
y.value_counts()
# Out:
# 9     686
# 10    625
# 8     566
# 11    472
# 7     391
# 6     258
# 12    251
# 13    199
# 14    119
# 5     113
# 15    102
# 16     62
# 17     53
# 4      49
# 18     39
# 19     32
# 3      10
# Name: Rings, dtype: int64

# %%
sns.countplot(abl['Rings'])
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rings', ylabel='count'>

# %%
from imblearn.over_sampling import SMOTE

# %%
smt = SMOTE()
X,Y = smt.fit_resample(x,y,)
X,Y
# Out:
# (       Sex    Length  Diameter    Height  Whole weight  Shucked weight  \
#  0      2.0  0.455000  0.365000  0.095000      0.514000        0.224500
#  1      2.0  0.350000  0.265000  0.090000      0.225500        0.099500
#  2      0.0  0.530000  0.420000  0.135000      0.677000        0.256500
#  3      2.0  0.440000  0.365000  0.125000      0.516000        0.215500
#  4      1.0  0.330000  0.255000  0.080000      0.205000        0.089500
#  ...    ...       ...       ...       ...           ...             ...
#  11657  2.0  0.651210  0.521831  0.190589      1.513224        0.618649
#  11658  2.0  0.617147  0.481576  0.190571      1.388081        0.514423
#  11659  2.0  0.555119  0.445119  0.178492      1.045756        0.362277
#  11660  0.0  0.566604  0.455535  0.172327      1.011129        0.351303
#  11661  0.0  0.567621  0.444405  0.154405      0.896923        0.333663
#
#         Viscera weight  Shell weight
#  0            0.101000      0.150000
# ...

# %%
X.shape
# Out:
# (11662, 8)

# %%
Y.shape
# Out:
# (11662,)

# %%
sns.countplot(Y)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='count'>

# %% [markdown]
# We used SMOTE function here to balanced the data.

# %% [markdown]
# ### Training Process

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
maxAccu = 0
maxRS = 0

for i in range(1,100):
    x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=.30,random_state=i)
    LR = LogisticRegression()
    LR.fit(x_train,y_train)
    pred_train = LR.predict(x_train)
    pred_test = LR.predict(x_test)
    acc_train = accuracy_score(y_train,pred_train)
    acc_test = accuracy_score(y_test,pred_test)
    print('training accuracy :',acc_train,'test accuracy is :',acc_test,'random_state is:',i)
    print()
# Out:
# training accuracy : 0.2654661276491486 test accuracy is : 0.27007716490425837 random_state is: 1
#
# training accuracy : 0.2674261913512189 test accuracy is : 0.2577879394112604 random_state is: 2
#
# training accuracy : 0.26228102413328436 test accuracy is : 0.26779079737067735 random_state is: 3
#
# training accuracy : 0.27391890236432687 test accuracy is : 0.25435838811088884 random_state is: 4
#
# training accuracy : 0.26191351218914616 test accuracy is : 0.2632180623035153 random_state is: 5
#
# training accuracy : 0.2677937032953571 test accuracy is : 0.26350385824521294 random_state is: 6
#
# training accuracy : 0.26718118338846014 test accuracy is : 0.25150042869391254 random_state is: 7
#
# training accuracy : 0.2657111356119074 test accuracy is : 0.2837953701057445 random_state is: 8
#
# training accuracy : 0.26681367144432194 test accuracy is : 0.27093455272935124 random_state is: 9
#
# ...

# %% [markdown]
# #### Train Test Split

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=.25,random_state=84)

# %%
x_train.shape
# Out:
# (8746, 8)

# %%
x_test.shape
# Out:
# (2916, 8)

# %%
y_train.shape
# Out:
# (8746,)

# %%
y_test.shape
# Out:
# (2916,)

# %% [markdown]
# ## Model Testing

# %%
def Model(model):
    model.fit(x_train,y_train)
    pred = model.predict(x_test)
    print('Accuracy',accuracy_score(y_test,pred))
    print(classification_report(y_test,pred))
    scr1 = cross_val_score(model,X,Y,cv=4)
    print('Cross validation score :',scr1.mean())

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

LR = LogisticRegression()
Model(LR)
# Out:
# Accuracy 0.2575445816186557
#               precision    recall  f1-score   support
#
#            3       0.60      0.98      0.74       166
#            4       0.42      0.30      0.35       174
#            5       0.42      0.42      0.42       175
#            6       0.28      0.38      0.32       166
#            7       0.22      0.25      0.23       194
#            8       0.24      0.30      0.27       197
#            9       0.22      0.29      0.25       168
#           10       0.25      0.12      0.17       161
#           11       0.21      0.39      0.27       162
#           12       0.05      0.01      0.02       185
#           13       0.05      0.01      0.01       184
#           14       0.11      0.09      0.10       159
#           15       0.09      0.10      0.10       165
#           16       0.22      0.31      0.26       162
#           17       0.23      0.06      0.10       161
#           18       0.15      0.24      0.18       161
# ...

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
Model(dt)
# Out:
# Accuracy 0.5781893004115226
#               precision    recall  f1-score   support
#
#            3       0.90      0.97      0.94       166
#            4       0.87      0.79      0.83       174
#            5       0.81      0.79      0.80       175
#            6       0.53      0.61      0.57       166
#            7       0.53      0.48      0.50       194
#            8       0.36      0.34      0.35       197
#            9       0.15      0.14      0.14       168
#           10       0.27      0.29      0.28       161
#           11       0.38      0.38      0.38       162
#           12       0.50      0.48      0.49       185
#           13       0.51      0.49      0.50       184
#           14       0.60      0.67      0.63       159
#           15       0.61      0.60      0.61       165
#           16       0.65      0.65      0.65       162
#           17       0.69      0.73      0.71       161
#           18       0.75      0.75      0.75       161
# ...

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
Model(rfc)
# Out:
# Accuracy 0.7181069958847737
#               precision    recall  f1-score   support
#
#            3       0.98      0.99      0.99       172
#            4       0.87      0.94      0.91       169
#            5       0.81      0.87      0.83       186
#            6       0.71      0.71      0.71       171
#            7       0.56      0.65      0.60       154
#            8       0.44      0.38      0.41       167
#            9       0.30      0.29      0.29       154
#           10       0.33      0.25      0.29       169
#           11       0.53      0.39      0.45       178
#           12       0.70      0.65      0.68       164
#           13       0.74      0.73      0.74       172
#           14       0.78      0.84      0.81       176
#           15       0.78      0.88      0.82       177
#           16       0.82      0.85      0.83       172
#           17       0.81      0.90      0.85       185
#           18       0.81      0.91      0.86       171
# ...

# %% [markdown]
# ### SVC

# %%
from sklearn.svm import SVC
svc = SVC()
Model(svc)
# Out:
# Accuracy 0.2674897119341564
#               precision    recall  f1-score   support
#
#            3       0.62      0.94      0.74       172
#            4       0.49      0.44      0.46       169
#            5       0.45      0.41      0.43       186
#            6       0.36      0.30      0.33       171
#            7       0.27      0.35      0.30       154
#            8       0.22      0.23      0.23       167
#            9       0.16      0.10      0.12       154
#           10       0.20      0.14      0.16       169
#           11       0.24      0.11      0.15       178
#           12       0.16      0.21      0.18       164
#           13       0.15      0.13      0.14       172
#           14       0.13      0.15      0.14       176
#           15       0.13      0.13      0.13       177
#           16       0.18      0.31      0.23       172
#           17       0.34      0.12      0.18       185
#           18       0.20      0.40      0.27       171
# ...

# %% [markdown]
# ### Extra Tree Classifier

# %%
from sklearn.ensemble import ExtraTreesClassifier
etc = ExtraTreesClassifier()
Model(etc)
# Out:
# Accuracy 0.75
#               precision    recall  f1-score   support
#
#            3       0.99      1.00      1.00       172
#            4       0.91      0.96      0.93       169
#            5       0.83      0.90      0.87       186
#            6       0.75      0.77      0.76       171
#            7       0.60      0.68      0.63       154
#            8       0.48      0.42      0.45       167
#            9       0.30      0.29      0.29       154
#           10       0.35      0.26      0.30       169
#           11       0.56      0.43      0.49       178
#           12       0.72      0.70      0.71       164
#           13       0.79      0.80      0.79       172
#           14       0.83      0.86      0.84       176
#           15       0.82      0.91      0.86       177
#           16       0.88      0.88      0.88       172
#           17       0.84      0.95      0.89       185
#           18       0.88      0.92      0.90       171
# ...

# %% [markdown]
# We test the different model as shown above. From model testing we can see that Extra Tree Classifier has the highest accuracy 75 percent.

# %% [markdown]
# So we will continue with Extra Tree Classifier.

# %% [markdown]
# ### Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'criterion':['gini','entropy'],"max_depth":['auto',2,4,6,8,10],'n_estimators':list(range(0,100))}

# %%
GCV = GridSearchCV(etc,parameters,cv=5,scoring='accuracy')
GCV.fit(x_train,y_train)
GCV.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 10, 'n_estimators': 88}

# %%
GCV.best_estimator_
# Out:
# ExtraTreesClassifier(criterion='entropy', max_depth=10, n_estimators=88)

# %%
etc = ExtraTreesClassifier(criterion='entropy', max_depth=10)
Model(etc)
# Out:
# Accuracy 0.5377229080932785
#               precision    recall  f1-score   support
#
#            3       0.73      1.00      0.84       166
#            4       0.70      0.52      0.59       174
#            5       0.62      0.64      0.63       175
#            6       0.47      0.60      0.53       166
#            7       0.46      0.45      0.45       194
#            8       0.36      0.39      0.38       197
#            9       0.26      0.22      0.24       168
#           10       0.29      0.18      0.22       161
#           11       0.38      0.33      0.35       162
#           12       0.66      0.26      0.37       185
#           13       0.71      0.39      0.51       184
#           14       0.55      0.58      0.56       159
#           15       0.63      0.62      0.63       165
#           16       0.66      0.72      0.69       162
#           17       0.62      0.73      0.67       161
#           18       0.55      0.78      0.64       161
# ...

# %%
accuracy_score(y_test,GCV_pred)
# Out:
# 0.5360082304526749

# %% [markdown]
# ### Saving the Model

# %%
import joblib
joblib.dump(GCV.best_estimator_,"Abalone.pkl")
# Out:
# ['Abalone.pkl']
