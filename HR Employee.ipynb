# %% [markdown]
# ## HR-EMPLOYEE-ATTRITION

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
hr = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
pd.options.display.max_columns=None
hr
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
hr.shape
# Out:
# (1470, 35)

# %%
hr.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# #### About the columns
#
# ##### Age - This column represents the age of an employee
#
# ##### Attrition - This column shows that either employee attrited or not.
#
# ##### Business Travel - This column represents the traveling history of an employee.
#
# ##### Daily Rate - This column represents the travel rate.
#
# ##### Department - This column shows from which department the employee is.
#
# ##### Diastance from home - It shows the distance from home to office.
#
# ##### Education - It represents the Education of an employee.
#
# ##### EducationField - It shows that from which field the employee complete his/her education.
#
# ##### EmployeeCount - Number of employee.
#
# ##### EmployeeNumber - Specific number which provides to each employee.
#
# ##### EnviornmentSatisfaction - Enviornment in office is satisfactory or not.
#
# ##### Gender - It shows the employee is male or female.
#
# ##### HourlyRate - Hourly rate of working.
#
# ##### JobInvolvement - It represents how much an employee is dedicated to their work.
#
# ##### JobLevel - This column shows the job level of an employee.
#
# ##### JobRole - It represents the Designation of an employee.
#
# ##### JobSatisfaction - It shows that, employee is satisfied or not with his job.
#
# ##### MaritalStatus - It represents is employee married, single or divorcee.
#
# ##### MonthlyIncome - It shows the monthly income of an employee.
#
# ##### NumCompaniesWorked - This column represents for many companies the employee worked.
#
# ##### Overtime - Is employee does overtime or not.
#
# ##### PercentSalaryHike - How much hike the employee get in salary.
#
# ##### PerformanceRating - It shows the rating of an employee based on his/her performance.
#
# ##### TotalWorkingYears - It shows from how many years the employee worked.
#
# ##### WorkLifeBalance - This column represents the balance between work and life.
#
# ##### YearsAtCompany - This shows years of working of an employee in company.
#
# ##### YearsWithCurrManager - This shows the years of working with current manager.

# %%
hr.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ##### We dont have any null values in our dataset.

# %%
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ##### We can see the information about HR dataset. It shows the non null values and datatypes of columns in given dataset. It shows how much memory the dataset used.

# %%
l = ['EmployeeCount','JobLevel','Over18','StandardHours']
hr.drop(l,axis=1,inplace=True)

# %% [markdown]
# ##### We drop the column because it have not much effect on dataset.

# %% [markdown]
# ### Data Analysis and Visualization

# %% [markdown]
# ### Visualization

# %%
sns.countplot(x = 'Attrition', data=hr)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# ##### Above plot tells that number of employees who wants attrition is less than the employee who do not want attrition.

# %%
plt.figure(figsize=(13,9))
sns.countplot(x = 'Age', hue = 'Attrition', data=hr)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# ##### From above countplot we can say that, average age of employees never wants attrition.

# %%
plt.figure(figsize=(7,7))
sns.countplot(x = 'Department', hue= 'Attrition', data=hr )
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %% [markdown]
# ##### Employee from Research and Developement department has highest in number who never wants Attrition.

# %%
plt.figure(figsize=(10,7))
sns.countplot(x = 'EducationField', hue='Attrition', data=hr)
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='count'>

# %% [markdown]
# ##### Employees from LifeScience Education field are highest in number who never wants Attrition.

# %%
plt.figure(figsize=(5,5))
sns.countplot(x = 'Gender', hue='Attrition',data=hr)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# ##### Number of males is more than Females who dont want Attrition.

# %%
plt.figure(figsize=(5,5))
sns.countplot(x = 'MaritalStatus', hue='Attrition',data=hr)
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %% [markdown]
# ##### Number of single employee is more, who wants Attrition.

# %%
plt.figure(figsize=(10,7))
sns.countplot(x = 'TotalWorkingYears', hue='Attrition',data=hr)
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='count'>

# %% [markdown]
# ##### Employees who have less number of experience,wants Attrition than the employees with more experience.

# %% [markdown]
# #### Description

# %%
hr.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# std        602.024335                 1.093082    20.329428        0.711561
# min          1.000000                 1.000000    30.000000        1.000000
# ...

# %% [markdown]
# ##### The description of dataset shows the Count,Standard Deviation,Mean,Minimum Value,Maximum Value of each column.

# %%
plt.figure(figsize=(25,12))
sns.heatmap(hr.describe(),annot = True, fmt = '.2f', linewidths=2)
plt.title('HR Description')
# Out:
# Text(0.5, 1.0, 'HR Description')

# %% [markdown]
# ### Outcome of Description
#
# #### Description of HR dataset helps us to clean the data.
#
# Age - 1.Mean = 36.92, 2.Std = 9.14, 3.Min = 18, Max = 60
#
# Daily Rate - 1.Mean = 802.49, 2.Std = 403.51, 3.Min = 102, Max = 1499
#
# DistanceFromHome - 1.Mean = 9.19, 2.Std = 8.11, 3.Min = 1, Max = 29
#
# Education - 1.Mean = 2.91, 2.Std = 1.02, 3.Min = 1, Max = 5
#
# EmployeeNumber - 1.Mean = 1024.87, 2.Std = 602.02, 3.Min = 1, Max = 2068
#
# EnviornmentSatisfaction - 1.Mean = 2.72, 2.Std = 1.09, 3.Min = 1, Max = 4
#
# HourlyRate - 1.Mean = 65.89, 2.Std = 20.33, 3.Min = 30, Max = 100
#
# JobInvolvement - 1.Mean = 2.73, 2.Std = 0.71, 3.Min = 1, Max = 4
#
# JobSatisfaction - 1.Mean = 2.73, 2.Std = 1.10, 3.Min = 1, Max = 4
#
# MonthlyIncome - 1.Mean = 6502.93, 2.Std = 4707.96, 3.Min = 1009, Max = 19999
#
# MonthlyRate - 1.Mean = 14313.10, 2.Std = 7117.79, 3.Min = 2094, Max = 26999
#
# NumCompaniesWorked - 1.Mean = 2.69, 2.Std = 2.50, 3.Min = 0, Max = 9
#
# PercentSalaryHike - 1.Mean = 15.21, 2.Std = 3.66, 3.Min = 11, Max = 25
#
# PerformanceRating - 1.Mean = 3.15, 2.Std = 0.36, 3.Min = 3, Max = 4
#
# RelationshipSatisfaction - 1.Mean = 2.71, 2.Std = 1.08, 3.Min = 1, Max = 4
#
# StockOPtionLevel - 1.Mean = 0.79, 2.Std = 0.85, 3.Min = 0, Max = 3
#
# TotalWorkingYears - 1.Mean = 11.28, 2.Std = 7.78, 3.Min = 0, Max = 40
#
# TrainingTimesLastYear - 1.Mean = 2.80, 2.Std = 1.29, 3.Min = 0, Max = 6
#
# WorkLifeBalance - 1.Mean = 2.76, 2.Std = 0.71, 3.Min = 1, Max = 4
#
# YearsAtCompany - 1.Mean = 7.01, 2.Std = 6.13, 3.Min = 0, Max = 40
#
# YearsInCurrentRole - 1.Mean = 4.23, 2.Std = 3.62, 3.Min = 0, Max = 18
#
# YearsSinceLastPromotion - 1.Mean = 2.19, 2.Std = 3.22, 3.Min = 0, Max = 15
#
# YearsWithCurrManager - 1.Mean = 4.12, 2.Std = 3.57, 3.Min = 0, Max = 17

# %% [markdown]
# ### Correlation

# %%
hr.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# MonthlyIncome             0.497855   0.007707         -0.017014   0.094961
# MonthlyRate               0.028051  -0.032182          0.027473  -0.026084
# ...

# %%
plt.figure(figsize=(25,15))
sns.heatmap(hr.corr(),annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### As we seen that from above plot maximum columns are highly correlated with each other. Age and Monthly Income are highly correlated with Total Working Years. Years at Company,Years in Current Role,Years since last Promotion and Years with Curr Manager are correlated with each other.

# %%
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeNumber            1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   object
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobRole                   1470 non-null   object
# ...

# %% [markdown]
# ##### There is no null value in hr dataset.

# %%
non_cat_columns = ['DailyRate','HourlyRate','MonthlyIncome','MonthlyRate']

# %%
descrete_columns = ['Age','DistanceFromHome','Education','EnvironmentSatisfaction','JobInvolvement','JobSatisfaction','NumCompaniesWorked','PercentSalaryHike','PerformanceRating','RelationshipSatisfaction','StockOptionLevel','TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Skewness

# %%
hr.skew()
# Out:
# Age                         0.413286
# DailyRate                  -0.003519
# DistanceFromHome            0.958118
# Education                  -0.289681
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobSatisfaction            -0.329672
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# YearsInCurrentRole          0.917363
# YearsSinceLastPromotion     1.984290
# YearsWithCurrManager        0.833451
# dtype: float64

# %%
hr.plot(kind = 'density',subplots = True, layout = (6,6), figsize=(28,20), sharex=False)
plt.show()

# %% [markdown]
# ##### We can see the skewness in data for multiple columns.

# %%
hr.skew().sort_values(ascending = False)
# Out:
# YearsSinceLastPromotion     1.984290
# PerformanceRating           1.921883
# YearsAtCompany              1.764529
# MonthlyIncome               1.369817
# TotalWorkingYears           1.117172
# NumCompaniesWorked          1.026471
# StockOptionLevel            0.968980
# DistanceFromHome            0.958118
# YearsInCurrentRole          0.917363
# YearsWithCurrManager        0.833451
# PercentSalaryHike           0.821128
# TrainingTimesLastYear       0.553124
# Age                         0.413286
# MonthlyRate                 0.018578
# EmployeeNumber              0.016574
# DailyRate                  -0.003519
# HourlyRate                 -0.032311
# Education                  -0.289681
# RelationshipSatisfaction   -0.302828
# EnvironmentSatisfaction    -0.321654
# JobSatisfaction            -0.329672
# JobInvolvement             -0.498419
# WorkLifeBalance            -0.552480
# dtype: float64

# %% [markdown]
# ##### Lets set the skewness threshold as 0.75, we see that
#
# YearsSinceLastPromotion   -   1.984290
#
# PerformanceRating         -   1.921883
#
# YearsAtCompany            -   1.764529
#
# MonthlyIncome             -   1.369817
#
# TotalWorkingYears         -   1.117172
#
# NumCompaniesWorked        -   1.026471
#
# StockOptionLevel          -   0.968980
#
# DistanceFromHome          -   0.958118
#
# YearsInCurrentRole        -   0.917363
#
# YearsWithCurrManager      -   0.833451
#
# PercentSalaryHike         -   0.821128
#
# ##### are above the threshold.

# %% [markdown]
# ### Data Conversion

# %%
from sklearn.preprocessing import LabelEncoder
lec = LabelEncoder()

# %%
for i in hr.columns:
    if hr[i].dtypes == object:
        hr[i] = lec.fit_transform(hr[i].values.reshape(-1,1))

# %%
hr
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %%
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int32
#  2   BusinessTravel            1470 non-null   int32
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int32
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   int32
#  8   EmployeeNumber            1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   int32
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobRole                   1470 non-null   int32
# ...

# %% [markdown]
# ##### We do not have any Catagorical column.

# %% [markdown]
# ### Checking Outliers

# %%
hr_non_cat_columns = hr[non_cat_columns]
hr_non_cat_columns
# Out:
#       DailyRate  HourlyRate  MonthlyIncome  MonthlyRate
# 0          1102          94           5993        19479
# 1           279          61           5130        24907
# 2          1373          92           2090         2396
# 3          1392          56           2909        23159
# 4           591          40           3468        16632
# ...         ...         ...            ...          ...
# 1465        884          41           2571        12290
# 1466        613          42           9991        21457
# 1467        155          87           6142         5174
# 1468       1023          63           5390        13243
# 1469        628          82           4404        10228
#
# [1470 rows x 4 columns]

# %%
hr_descrete_columns = hr[descrete_columns]
hr_descrete_columns
# Out:
#       Age  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0      41                 1          2                        2
# 1      49                 8          1                        3
# 2      37                 2          2                        4
# 3      33                 3          4                        4
# 4      27                 2          1                        1
# ...   ...               ...        ...                      ...
# 1465   36                23          2                        3
# 1466   39                 6          1                        4
# 1467   27                 4          3                        2
# 1468   49                 2          3                        4
# 1469   34                 8          3                        2
#
#       JobInvolvement  JobSatisfaction  NumCompaniesWorked  PercentSalaryHike  \
# 0                  3                4                   8                 11
# ...

# %%
hr_non_cat_columns.plot(kind='box',subplots=True,layout=(5,5),figsize=(30,25))
plt.show()

hr_descrete_columns.plot(kind='box',subplots=True,layout=(5,5),figsize=(30,25))
plt.show()

# %% [markdown]
# ##### We can see outliers presents in
# MonthlyIncome
#
# TotalWorkingYears
#
# YearsAtCompany
#
# YearsSinceLastPromotion
#
# TrainingTimesLastYear
#
# NumCompaniesWork
#
# PerformanceRating
#
# YearsInCurrentRole

# %% [markdown]
# ### Removing Outliers

# %% [markdown]
# #### Z Score Technique

# %%
from scipy.stats import zscore

z = np.abs(zscore(hr))
z.shape
# Out:
# (1470, 31)

# %%
hr = hr[(z<3).all(axis=1)]
hr.shape
# Out:
# (1387, 31)

# %% [markdown]
# ### Percentage Data Loss

# %%
percentage_data_loss = (1470-1387)/1470*100
percentage_data_loss
# Out:
# 5.646258503401361

# %% [markdown]
# ### VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calculate_vif(dataset):
    vif = pd.DataFrame()
    vif['Features'] = dataset.columns
    vif['VIF_Values'] = [variance_inflation_factor(dataset.values,i) for i in range(dataset.shape[1])]
    return(vif.sort_values(by='VIF_Values',ascending = False))

# %%
calculate_vif(hr_non_cat_columns)
# Out:
#         Features  VIF_Values
# 1     HourlyRate    5.868839
# 0      DailyRate    4.070855
# 3    MonthlyRate    4.045189
# 2  MonthlyIncome    2.668589

# %% [markdown]
# ##### Lets keep the threshold for VIF as 10, we see all the values below the threshold.

# %% [markdown]
# ### Splitting the Data Frame in hrx and hry

# %%
hrx = hr.drop('Attrition',axis=1)
hrx.shape
# Out:
# (1387, 30)

# %%
hry = hr['Attrition']
hry.shape
# Out:
# (1387,)

# %% [markdown]
# ### Balancing the Dataset

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE()
x,y = sm.fit_resample(hrx,hry)

# %%
x.shape
# Out:
# (2316, 30)

# %%
print(y.shape)
print(y.value_counts())
print()
sns.countplot(y)
plt.show()
# Out:
# (2316,)
# 0    1158
# 1    1158
# Name: Attrition, dtype: int64

# %% [markdown]
# ##### We normalize the data using SMOTE.

# %% [markdown]
# ### Normalizing Using Power Transform

# %%
from sklearn.preprocessing import power_transform
x_new = power_transform(x)

# %%
type(x_new)
# Out:
# numpy.ndarray

# %%
x = pd.DataFrame(x_new,columns=x.columns)
x
# Out:
#            Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0     0.768711        0.789042   0.849339    1.520880         -1.612752
# 1     1.499333       -1.070256  -1.376523   -0.345919          0.109934
# 2     0.352815        0.789042   1.447889   -0.345919         -1.185024
# 3    -0.106411       -1.070256   1.488438   -0.345919         -0.865781
# 4    -0.900603        0.789042  -0.423537   -0.345919         -1.185024
# ...        ...             ...        ...         ...               ...
# 2311  1.582808        0.789042  -0.185818   -0.345919         -0.608735
# 2312  1.148955        0.789042   0.894930   -0.345919          0.484854
# 2313 -1.524483       -1.070256   1.333869   -2.402746          0.109934
# 2314  1.239155       -1.070256   0.009492   -0.345919          0.484854
# 2315  0.460512        0.789042   0.412454   -0.345919         -0.039070
#
#       Education  EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# ...

# %%
x[descrete_columns].skew(),x[non_cat_columns].skew()
# Out:
# (Age                        -0.001910
#  DistanceFromHome           -0.042867
#  Education                  -0.074288
#  EnvironmentSatisfaction    -0.111747
#  JobInvolvement             -0.060722
#  JobSatisfaction            -0.122397
#  NumCompaniesWorked          0.002591
#  PercentSalaryHike           0.101750
#  PerformanceRating           0.000000
#  RelationshipSatisfaction   -0.123212
#  StockOptionLevel            0.341529
#  TotalWorkingYears          -0.020121
#  TrainingTimesLastYear       0.073077
#  WorkLifeBalance            -0.048880
#  YearsAtCompany             -0.016395
#  YearsInCurrentRole         -0.031622
#  YearsSinceLastPromotion     0.263779
#  YearsWithCurrManager       -0.030095
#  dtype: float64,
#  DailyRate       -0.151564
#  HourlyRate      -0.077303
#  MonthlyIncome    0.052030
#  MonthlyRate     -0.178599
#  dtype: float64)

# %% [markdown]
#  ##### We see all the values are well within the threshold for skew(0.75)

# %% [markdown]
# ### Scaling the Model

# %%
from sklearn.preprocessing import MinMaxScaler
mn = MinMaxScaler()
mn
# Out:
# MinMaxScaler()

# %% [markdown]
# ### Training Process

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
lr = LogisticRegression()
lr
# Out:
# LogisticRegression()

# %% [markdown]
# ### Best Random State

# %%
maxAccu = 0
maxRs = 0

for i in range(1,100):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30,random_state=i)
    lr.fit(x_train,y_train)
    predhr = lr.predict(x_test)
    acc = accuracy_score(y_test,predhr)
    if acc>maxAccu:
        maxAccu=acc
        maxRs = i
print('Best Accuracy is',maxAccu,'on Random state',maxRs)
# Out:
# Best Accuracy is 0.8647482014388489 on Random state 75

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30,random_state=75)

# %%
x_train.shape
# Out:
# (1621, 30)

# %%
x_test.shape
# Out:
# (695, 30)

# %%
y_train.shape
# Out:
# (1621,)

# %%
y_test.shape
# Out:
# (695,)

# %% [markdown]
# ### Model Testing

# %%
def Model(model):
    model.fit(x_train,y_train)
    pred = model.predict(x_test)
    print('Accuracy',accuracy_score(y_test,pred))
    print(classification_report(y_test,pred))
    scr1 = cross_val_score(model,x,y,cv=5)
    print('Cross validation score :',scr1.mean())

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
Model(lr)
# Out:
# Accuracy 0.8647482014388489
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87       345
#            1       0.89      0.84      0.86       350
#
#     accuracy                           0.86       695
#    macro avg       0.87      0.86      0.86       695
# weighted avg       0.87      0.86      0.86       695
#
# Cross validation score : 0.7988660907127431

# %% [markdown]
# #### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()
Model(dt)
# Out:
# Accuracy 0.8057553956834532
#               precision    recall  f1-score   support
#
#            0       0.83      0.77      0.80       345
#            1       0.79      0.84      0.81       350
#
#     accuracy                           0.81       695
#    macro avg       0.81      0.81      0.81       695
# weighted avg       0.81      0.81      0.81       695
#
# Cross validation score : 0.6459633574141656

# %% [markdown]
# #### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
Model(rf)
# Out:
# Accuracy 0.9064748201438849
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91       345
#            1       0.93      0.88      0.90       350
#
#     accuracy                           0.91       695
#    macro avg       0.91      0.91      0.91       695
# weighted avg       0.91      0.91      0.91       695
#
# Cross validation score : 0.8260519848067327

# %% [markdown]
# #### Extra Tree Classifier

# %%
from sklearn.tree import ExtraTreeClassifier

etc = ExtraTreeClassifier()
Model(etc)
# Out:
# Accuracy 0.7856115107913669
#               precision    recall  f1-score   support
#
#            0       0.80      0.75      0.78       345
#            1       0.77      0.82      0.79       350
#
#     accuracy                           0.79       695
#    macro avg       0.79      0.79      0.79       695
# weighted avg       0.79      0.79      0.79       695
#
# Cross validation score : 0.756962649884561

# %% [markdown]
# #### Service Vector Classifier

# %%
from sklearn.svm import SVC

svc = SVC()
Model(svc)
# Out:
# Accuracy 0.902158273381295
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90       345
#            1       0.92      0.88      0.90       350
#
#     accuracy                           0.90       695
#    macro avg       0.90      0.90      0.90       695
# weighted avg       0.90      0.90      0.90       695
#
# Cross validation score : 0.8601986668652714

# %% [markdown]
# ##### We can see that Random Forest Classifier model performs better than the other models,so we will continue with Random Forest Classifier.

# %% [markdown]
# ### Hyper Parameter Tuning

# %%
RandomForestClassifier()
# Out:
# RandomForestClassifier()

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'criterion' : ["gini", "entropy"],
             'max_depth' : [2,4,6,8,10],
              'max_features' : ["auto", "sqrt", "log2"],
             'class_weight' : ["balanced", "balanced_subsample"]}

# %%
GSC = GridSearchCV(RandomForestClassifier(),parameters,cv=5,scoring='accuracy')
GSC.fit(x_train,y_train)
GSC.best_params_
# Out:
# {'class_weight': 'balanced',
#  'criterion': 'entropy',
#  'max_depth': 10,
#  'max_features': 'log2'}

# %%
GSC_pred = GSC.best_estimator_.predict(x_test)
accuracy_score(y_test,GSC_pred)
# Out:
# 0.9107913669064748

# %% [markdown]
# ### ROC AUC Plot

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(GSC.best_estimator_,x_test,y_test)
plt.title('ROC AUC Plot')
plt.show()

# %% [markdown]
# ### Save the Model

# %%
import joblib
joblib.dump(GSC.best_estimator_,'HR.pkl')
# Out:
# ['HR.pkl']

# %% [markdown]
# ##### We saved the model.
